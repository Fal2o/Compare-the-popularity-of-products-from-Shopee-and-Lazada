# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df_lazada = pd.read_csv("df_lazada.csv")
df_shopee = pd.read_csv("df_shopee.csv")

# %%
df_shopee
# Out:
#                                                 Product  Price  Quantity  \
# 0     Medmaker Vitamin E Cream เมดเมคเกอร์ วิตามินอี...     57       700
# 1     Tomei Facial Moisturizer โทเมอิ เฟเชียล มอยเจอ...    139      5700
# 2     กล่องอาหารกลางวัน กล่องเก็บอาหาร ทนความร้อน เข...     16     18100
# 3     กล่องข้าวฟางข้าวสาลี พร้อมอุปกรณ์ช้อนตะเกียบสแ...     51      9100
# 4     (รหัส s12)50 ใบ ซองซิปล็อคเนื้อด้าน ถุงซิปล็อก...     45     24400
# ...                                                 ...    ...       ...
# 5065  แคบหมูแผ่น กรอบอร่อยไร้มัน! ถุงใหญ่จุใจ35฿!! ท...     35       700
# 5066  📌 เมนู น้ำพริกกากหมู/กากหมูคั่วพริก กร๊อบกรอบ ...     69     21700
# 5067  1kg. หนังไก่ทอดกรอบ(ทอดเกลือ) กรอบอร่อยทานเพลิ...     99      6600
# 5068  [ลูกค้าใหม่ 1 บาท] 🐝 รวงผึ้ง รังผึ้งสด พิเศษชิ...     75      1900
# 5069            น้ำพริกหมูกระจก น้ำพริกกากหมู 500/1000g    200     19700
#
#             Address              Type
# 0            กระบี่           ความงาม
# ...

# %%
df_lazada
# Out:
#                                                 Product  \
# 0     QiaoYiLuo  ขายดี💜จัดส่งทุกวัน รองเท้าผ้าใบผช ร...
# 1     🔥สินค้าขายดี🔥กระเป๋าผู้หญิง Tintinfashion กระเ...
# 2     [10-30 ชิ้น] ไม้แขวนเสื้อ ไม้แขวนเสื้อสแตนเลส ...
# 3     ไม้ถูพื้น ไม้ม๊อบ ถังถูพื้น ไม้ม๊อบถูพื้น ไม้ม...
# 4     เสื้อยืดแขนสั้นพร้อมส่ง 10สี ลายการ์ตูน ขายดีต...
# ...                                                 ...
# 4599  Beautifultime ชุดเดรสยาวลายดอกไม้สายเดี่ยวฤดูร...
# 4600  Beautifultime ชุดสตรี,แขนกุด Sequined Patchwor...
# 4601  Beautifultimeชุดชั้นในสตรีแฟชั่นสองชิ้นตาข่ายส...
# 4602        เสื้อแฟชั่น มือสอง ถ่ายจากสินค้าจริงทุกตัว
# 4603            เสื้อคอกลม แฟชั่นเกาหลีเกาใจ พร้อมส่ง
#
#                                       New_Column   Price  Quantity  \
# 0        79.0074% Off9,999+ ชิ้น(3691)ฉะเชิงเทรา   79.00      3691
# 1       32.0068% Off9,999+ ชิ้น(8632)สมุทรปราการ   32.00      8632
# 2     25.9357% Off100k+ ชิ้น(33188)กรุงเทพมหานคร   25.93     33188
# ...

# %%
# เพิ่มคอลัมน์ 'Platform' เพื่อระบุแหล่งที่มาของข้อมูล
df_shopee['Platform'] = 'Shopee'
df_lazada['Platform'] = 'Lazada'

print("DataFrame ของ Shopee หลังจากปรับชื่อคอลัมน์:")
print(df_shopee.head())
print("\nDataFrame ของ Lazada หลังจากปรับชื่อคอลัมน์:")
print(df_lazada.head())
# Out:
# DataFrame ของ Shopee หลังจากปรับชื่อคอลัมน์:
#                                              Product  Price  Quantity  \
# 0  Medmaker Vitamin E Cream เมดเมคเกอร์ วิตามินอี...     57       700
# 1  Tomei Facial Moisturizer โทเมอิ เฟเชียล มอยเจอ...    139      5700
# 2  กล่องอาหารกลางวัน กล่องเก็บอาหาร ทนความร้อน เข...     16     18100
# 3  กล่องข้าวฟางข้าวสาลี พร้อมอุปกรณ์ช้อนตะเกียบสแ...     51      9100
# 4  (รหัส s12)50 ใบ ซองซิปล็อคเนื้อด้าน ถุงซิปล็อก...     45     24400
#
#          Address              Type Platform
# 0         กระบี่           ความงาม   Shopee
# 1         กระบี่           ความงาม   Shopee
# 2  กรุงเทพมหานคร             อาหาร   Shopee
# 3  กรุงเทพมหานคร  เครื่องใช้ในบ้าน   Shopee
# 4  กรุงเทพมหานคร             อาหาร   Shopee
#
# DataFrame ของ Lazada หลังจากปรับชื่อคอลัมน์:
#                                              Product  \
# 0  QiaoYiLuo  ขายดี💜จัดส่งทุกวัน รองเท้าผ้าใบผช ร...
# 1  🔥สินค้าขายดี🔥กระเป๋าผู้หญิง Tintinfashion กระเ...
# ...

# %%
df_all = pd.concat([df_shopee, df_lazada], ignore_index=True)
print("\nDataFrame ที่รวมกัน:")
df_all.drop(columns=['New_Column'],inplace=True)
(df_all.head())
# Out:
# DataFrame ที่รวมกัน:
#                                              Product  Price  Quantity  \
# 0  Medmaker Vitamin E Cream เมดเมคเกอร์ วิตามินอี...   57.0       700
# 1  Tomei Facial Moisturizer โทเมอิ เฟเชียล มอยเจอ...  139.0      5700
# 2  กล่องอาหารกลางวัน กล่องเก็บอาหาร ทนความร้อน เข...   16.0     18100
# 3  กล่องข้าวฟางข้าวสาลี พร้อมอุปกรณ์ช้อนตะเกียบสแ...   51.0      9100
# 4  (รหัส s12)50 ใบ ซองซิปล็อคเนื้อด้าน ถุงซิปล็อก...   45.0     24400
#
#          Address              Type Platform
# 0         กระบี่           ความงาม   Shopee
# 1         กระบี่           ความงาม   Shopee
# 2  กรุงเทพมหานคร             อาหาร   Shopee
# 3  กรุงเทพมหานคร  เครื่องใช้ในบ้าน   Shopee
# 4  กรุงเทพมหานคร             อาหาร   Shopee

# %%
thai_to_english_type_mapping = {
    'กีฬาและนันทนาการกลางแจ้ง': 'Sports & Outdoor Recreation',
    'ของใช้ส่วนตัวและเครื่องประดับ': 'Personal Care & Accessories',
    'ความงาม': 'Beauty',
    'มือถือและเครื่องใช้ไฟฟ้า': 'Mobile & Electronics',
    'สินค้าเพื่อสุขภาพ': 'Health & Wellness',
    'อาหาร': 'Food',
    'เครื่องใช้ในบ้าน': 'Home Appliances',
    'เฟอร์นิเจอร์': 'Furniture',
    'แฟชั่น': 'Fashion' # เพิ่ม 'แฟชั่น' เข้าไปด้วยถ้ามีในข้อมูลจริงของคุณ
    # เพิ่มประเภทสินค้าอื่นๆ ที่มีใน DataFrame ของคุณใน Dictionary นี้
}

# ใช้ .map() เพื่อแทนที่ค่าใน Column 'Type' โดยใช้ Dictionary Mapping
df_all['Type_Eng'] = df_all['Type'].map(thai_to_english_type_mapping)

# แสดงผล DataFrame (เฉพาะบางส่วนเพื่อตรวจสอบ)
(df_all[['Type', 'Type_Eng']].head()) # แสดง Column 'Type' เดิม และ 'Type_Eng' ที่สร้างใหม่
# Out:
#                Type         Type_Eng
# 0           ความงาม           Beauty
# 1           ความงาม           Beauty
# 2             อาหาร             Food
# 3  เครื่องใช้ในบ้าน  Home Appliances
# 4             อาหาร             Food

# %%
df_all.drop(columns=['Type'],inplace=True)
df_all.rename(columns={'Type_Eng': 'Type'}, inplace=True)
df_all
# Out:
#                                                 Product  Price  Quantity  \
# 0     Medmaker Vitamin E Cream เมดเมคเกอร์ วิตามินอี...   57.0       700
# 1     Tomei Facial Moisturizer โทเมอิ เฟเชียล มอยเจอ...  139.0      5700
# 2     กล่องอาหารกลางวัน กล่องเก็บอาหาร ทนความร้อน เข...   16.0     18100
# 3     กล่องข้าวฟางข้าวสาลี พร้อมอุปกรณ์ช้อนตะเกียบสแ...   51.0      9100
# 4     (รหัส s12)50 ใบ ซองซิปล็อคเนื้อด้าน ถุงซิปล็อก...   45.0     24400
# ...                                                 ...    ...       ...
# 9669  Beautifultime ชุดเดรสยาวลายดอกไม้สายเดี่ยวฤดูร...  184.0        35
# 9670  Beautifultime ชุดสตรี,แขนกุด Sequined Patchwor...  200.0        48
# 9671  Beautifultimeชุดชั้นในสตรีแฟชั่นสองชิ้นตาข่ายส...   77.0        17
# 9672        เสื้อแฟชั่น มือสอง ถ่ายจากสินค้าจริงทุกตัว    59.0         4
# 9673            เสื้อคอกลม แฟชั่นเกาหลีเกาใจ พร้อมส่ง     51.7         6
#
#             Address Platform             Type
# ...

# %%
print("\nสถิติเชิงพรรณนาของ Price และ Quantity:")
print(df_all[['Price', 'Quantity']].describe())
# Out:
# สถิติเชิงพรรณนาของ Price และ Quantity:
#               Price       Quantity
# count   9674.000000    9674.000000
# mean     550.032964    7659.324995
# std     2106.204360   34301.265692
# min        1.000000       0.000000
# 25%       60.160000      48.000000
# 50%      149.000000     364.000000
# 75%      390.000000    2800.000000
# max    99999.000000  853400.000000

# %%
platform_comparison = df_all.groupby('Platform')[['Price', 'Quantity']].mean()
print("\nเปรียบเทียบค่าเฉลี่ย Price และ Quantity ระหว่าง Platform:")
print(platform_comparison)
# Out:
# เปรียบเทียบค่าเฉลี่ย Price และ Quantity ระหว่าง Platform:
#                Price      Quantity
# Platform
# Lazada    117.334902    548.453084
# Shopee    942.960355  14116.613807

# %%
province_analysis = df_all.groupby('Address').agg(
    จำนวนสินค้า=('Address', 'count'),
    ราคาเฉลี่ย=('Price', 'mean')
).reset_index()
print("\nวิเคราะห์ข้อมูลตามจังหวัด:")
(province_analysis)
# Out:
# วิเคราะห์ข้อมูลตามจังหวัด:
#                                            Address  จํานวนสินค้า   ราคาเฉลี่ย
# 0    เทร์นงานเซ็ตคู่กระโป฿259.0013% Off104 ชิ้น(25             2   259.000000
# 1                                           กระบี่            10    40.327000
# 2                                    กรุงเทพมหานคร          4050   620.147773
# 3                                        กาญจนบุรี             7  1081.285714
# 4                                        กาฬสินธุ์             2   169.000000
# ..                                             ...           ...          ...
# 74                                       เชียงใหม่            52   557.076923
# 75                                        เพชรบุรี             3    48.666667
# 76                                       เพชรบูรณ์             7   152.142857
# 77                                             เลย             4   119.750000
# 78                                            แพร่            38   115.236842
#
# ...

# %%
type_analysis = df_all.groupby('Type').agg(
    จำนวนสินค้า=('Type', 'count'),
    ราคาเฉลี่ย=('Price', 'mean')
).reset_index()
print("\nวิเคราะห์ข้อมูลตามประเภทสินค้า:")
(type_analysis)
# Out:
# วิเคราะห์ข้อมูลตามประเภทสินค้า:
#                             Type  จํานวนสินค้า   ราคาเฉลี่ย
# 0       กีฬาและนันทนาการกลางแจ้ง             5    81.000000
# 1  ของใช้ส่วนตัวและเครื่องประดับ            21    91.000000
# 2                        ความงาม          2315   405.736454
# 3       มือถือและเครื่องใช้ไฟฟ้า          1118  2274.495000
# 4              สินค้าเพื่อสุขภาพ           166   469.683193
# 5                          อาหาร          1513   465.265036
# 6               เครื่องใช้ในบ้าน          1067   327.980619
# 7                   เฟอร์นิเจอร์            24  1842.041667
# 8                         แฟชั่น          3445   191.715489

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# ตัวอย่าง Bar chart เปรียบเทียบราคาเฉลี่ยระหว่าง Platform
plt.figure(figsize=(8, 6))
sns.barplot(x='Platform', y='Price', data=df_all)
plt.title('เปรียบเทียบราคาเฉลี่ยระหว่าง Shopee และ Lazada')
plt.ylabel('ราคาเฉลี่ย')
plt.xlabel('Platform')
plt.show()

# ตัวอย่าง Histogram แสดงการกระจายตัวของราคา
plt.figure(figsize=(8, 6))
sns.histplot(df_all['Price'], bins=20, kde=True)
plt.title('การกระจายตัวของราคา')
plt.xlabel('ราคา')
plt.ylabel('ความถี่')
plt.show()

# ตัวอย่าง Boxplot เปรียบเทียบการกระจายตัวของราคาตาม Platform
plt.figure(figsize=(8, 6))
sns.boxplot(x='Platform', y='Price', data=df_all)
plt.title('การกระจายตัวของราคาตาม Platform')
plt.ylabel('ราคา')
plt.xlabel('Platform')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3593 (\N{THAI CHARACTER CHO CHING}) missing from font(s) DejaVu Sans.
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Bar chart เปรียบเทียบราคาเฉลี่ยระหว่าง Platform
plt.figure(figsize=(8, 6))
sns.barplot(x='Platform', y='Price', data=df_all)
plt.title('Average Price Comparison between Shopee and Lazada') # เปลี่ยน title เป็นอังกฤษ
plt.ylabel('Average Price') # เปลี่ยน ylabel เป็นอังกฤษ
plt.xlabel('Platform') # เปลี่ยน xlabel เป็นอังกฤษ
plt.show()
# แสดงผลเป็น [Image of Bar chart comparing average price between Shopee and Lazada]

# 2. Histogram แสดงการกระจายตัวของราคา
plt.figure(figsize=(8, 6))
sns.histplot(df_all['Price'], bins=20, kde=True)
plt.title('Price Distribution') # เปลี่ยน title เป็นอังกฤษ
plt.xlabel('Price') # เปลี่ยน xlabel เป็นอังกฤษ
plt.ylabel('Frequency') # เปลี่ยน ylabel เป็นอังกฤษ
plt.show()
# แสดงผลเป็น [Image of Histogram of price distribution]

# 3. Boxplot เปรียบเทียบการกระจายตัวของราคาตาม Platform
plt.figure(figsize=(8, 6))
sns.boxplot(x='Platform', y='Price', data=df_all)
plt.title('Price Distribution by Platform') # เปลี่ยน title เป็นอังกฤษ
plt.ylabel('Price') # เปลี่ยน ylabel เป็นอังกฤษ
plt.xlabel('Platform') # เปลี่ยน xlabel เป็นอังกฤษ
plt.show()
# แสดงผลเป็น [Image of Boxplot of price distribution by Platform]

# %%
# ... (ส่วน import library และการเตรียม DataFrame df_all เหมือนเดิม) ...
from collections import Counter
# Import the WordCloud class
from wordcloud import WordCloud

# --- 1. Word Cloud (ปรับส่วนนี้) ---
# เตรียมข้อมูลประเภทสินค้าจาก df_all เพื่อ Word Cloud
product_types = df_all['Type'].tolist() # ดึงข้อมูลจาก column 'Type' เป็น list
product_type_counts = Counter(product_types) # นับความถี่ของแต่ละประเภทสินค้า

wordcloud = WordCloud(width=800, height=400,
                      background_color='white').generate_from_frequencies(product_type_counts)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Product Type Word Cloud (Shopee & Lazada)', fontsize=14) # เปลี่ยน Title ให้สื่อความหมาย
plt.show()
# แสดงผลเป็น [Image of Product Type Word Cloud (Shopee & Lazada)]

# %%
# ... (ส่วน import library และการเตรียม DataFrame df_all เหมือนเดิม) ...

# --- 2. Bar Chart (ปรับส่วนนี้) ---
# เตรียมข้อมูลจำนวนสินค้าต่อประเภทสินค้าจาก df_all
type_counts_bar = df_all['Type'].value_counts().nlargest(20) # นับความถี่และเลือก Top 20 ประเภท
types_bar = type_counts_bar.index.tolist() # ดึงชื่อประเภทสินค้าจาก index
counts_bar = type_counts_bar.values.tolist() # ดึงค่าความถี่ (จำนวนสินค้า)

plt.figure(figsize=(12, 6))
sns.barplot(x=counts_bar, y=types_bar, palette="viridis")
plt.xlabel('Number of Products') # เปลี่ยน Label แกน X ให้สื่อความหมาย
plt.ylabel('Product Type') # เปลี่ยน Label แกน Y ให้สื่อความหมาย
plt.title('Number of Products per Product Type (Top 20)', fontsize=14) # เปลี่ยน Title
plt.gca().invert_yaxis()
plt.show()
# แสดงผลเป็น [Image of Bar Chart of Number of Products per Product Type (Top 20)]
# Out:
# <ipython-input-45-4210702683de>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=counts_bar, y=types_bar, palette="viridis")

# %%
# 3.1 ราคาขายเฉลี่ยของแต่ละประเภทสินค้า (Bar Chart)
avg_price_per_type = df_all.groupby('Type')['Price'].mean().sort_values(ascending=False) # ราคาเฉลี่ยต่อประเภทสินค้า

plt.figure(figsize=(14, 7))
sns.barplot(x=avg_price_per_type.values, y=avg_price_per_type.index, palette='plasma') # ใช้ palette 'plasma'
plt.xlabel('Average Price')
plt.ylabel('Product Type')
plt.title('ราคาขายเฉลี่ยต่อประเภทสินค้า')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Bar Chart of Average Price per Product Type]


# 3.1 เปรียบเทียบราคาสินค้าในประเภทเดียวกัน (Box Plot)
plt.figure(figsize=(16, 8))
sns.boxplot(x='Type', y='Price', data=df_all, palette='Set2') # ใช้ palette 'Set2'
plt.xlabel('Product Type')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right') # ปรับการหมุน และการจัดวาง tick labels แกน X
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Box Plot of Price Distribution per Product Type]
# Out:
# <ipython-input-51-05fe2b74c8d4>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_per_type.values, y=avg_price_per_type.index, palette='plasma') # ใช้ palette 'plasma'
# <ipython-input-51-05fe2b74c8d4>:10: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-51-05fe2b74c8d4>:10: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-51-05fe2b74c8d4>:10: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-51-05fe2b74c8d4>:10: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# 3.2 ความสัมพันธ์ระหว่างราคากับจำนวนสินค้าที่ขาย (Scatter Plot)
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Price', y='Quantity', data=df_all, alpha=0.5) # alpha=0.5 เพื่อให้จุดโปร่งแสง มองเห็นจุดที่ซ้อนกัน
plt.xlabel('Price')
plt.ylabel('Quantity Sold')
plt.title('ความสัมพันธ์ระหว่างราคาสินค้าและจำนวนที่ขาย')
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Scatter Plot of Price vs Quantity Sold]
# Out:
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-52-34d2475378d1>:7: UserWarning: Glyph 3633 (\N{THAI CHARACTER MAI HAN-AKAT}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# 4.1 สินค้าประเภทใดขายดีที่สุด (Bar Chart - จำนวนสินค้า)
best_selling_types_qty = df_all.groupby('Type')['Quantity'].sum().sort_values(ascending=False).head(10) # ประเภทสินค้าที่ขายดีที่สุด 10 อันดับแรก (วัดจากจำนวน)

plt.figure(figsize=(14, 7))
sns.barplot(x=best_selling_types_qty.values, y=best_selling_types_qty.index, palette='rocket') # ใช้ palette 'rocket'
plt.xlabel('Total Quantity Sold')
plt.ylabel('Product Type')
plt.title('ประเภทสินค้าที่ขายดีที่สุด (วัดจากจำนวนสินค้า) - Top 10')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Bar Chart of Best Selling Product Types by Quantity (Top 10)]


# 4.2 รายได้รวมของแต่ละประเภทสินค้า (Bar Chart - รายได้)
df_all['Revenue'] = df_all['Price'] * df_all['Quantity'] # สร้าง column 'Revenue' = Price * Quantity
revenue_per_type = df_all.groupby('Type')['Revenue'].sum().sort_values(ascending=False).head(10) # รายได้รวมต่อประเภทสินค้า

plt.figure(figsize=(14, 7))
sns.barplot(x=revenue_per_type.values, y=revenue_per_type.index, palette='mako') # ใช้ palette 'mako'
plt.xlabel('Total Revenue')
plt.ylabel('Product Type')
plt.title('รายได้รวมของแต่ละประเภทสินค้า - Top 10')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Bar Chart of Total Revenue per Product Type (Top 10)]
# Out:
# <ipython-input-54-d1b1c5198e0d>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=best_selling_types_qty.values, y=best_selling_types_qty.index, palette='rocket') # ใช้ palette 'rocket'
# <ipython-input-54-d1b1c5198e0d>:10: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-54-d1b1c5198e0d>:10: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-54-d1b1c5198e0d>:10: UserWarning: Glyph 3632 (\N{THAI CHARACTER SARA A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-54-d1b1c5198e0d>:10: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# 4.3 สัดส่วนยอดขายของแต่ละประเภทสินค้า (Pie Chart)
sales_proportion_type = df_all.groupby('Type')['Quantity'].sum().sort_values(ascending=False).head(10) # ยอดขายรวมต่อประเภทสินค้า (Top 10)

plt.figure(figsize=(10, 10))
plt.pie(sales_proportion_type, labels=sales_proportion_type.index, autopct='%1.1f%%', startangle=140,
        colors=sns.color_palette('pastel')) # ใช้ palette 'pastel' และปรับ startangle
plt.title('Proportion sales of each product type (Top 10)')
plt.axis('equal')  # ทำให้อัตราส่วนภาพเท่ากัน วงกลมไม่เบี้ยว
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Pie Chart of Sales Proportion per Product Type (Top 10)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate sales proportion
sales_proportion_type = df_all.groupby('Type')['Quantity'].sum().sort_values(ascending=False).head(10)

# Create figure with larger size and higher DPI for better quality
plt.figure(figsize=(12, 8), dpi=100)

# Create pie chart with improved styling
plt.pie(
    sales_proportion_type,
    labels=None,  # Remove labels from pie chart
    autopct='%.1f%%',
    startangle=90,
    counterclock=False,
    colors=sns.color_palette('husl', n_colors=10),
    wedgeprops={
        'edgecolor': 'white',
        'linewidth': 2,
        'antialiased': True
    },
    textprops={
        'fontsize': 12,
        'color': 'black'
    },
    pctdistance=0.85
)

# Make the chart circular
plt.axis('equal')

# Add legend
plt.legend(
    sales_proportion_type.index,
    title="Product Types",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1)
)

# Adjust layout to prevent text cutoff
plt.tight_layout()

# Show the plot
plt.show()

# %%
# 5.1 เปรียบเทียบราคาสินค้าขายดี vs. สินค้าขายไม่ดี (Box Plot)

# สร้าง Column 'Sales Category' แบ่งเป็น 'Best Seller' และ 'Others' โดยใช้ Top 10 ประเภทสินค้าขายดีจากข้อ 4.1
best_seller_types_list = best_selling_types_qty.index.tolist() # List ของประเภทสินค้าขายดี Top 10
df_all['Sales_Category'] = df_all['Type'].apply(lambda type: 'Best Seller' if type in best_seller_types_list else 'Others')

plt.figure(figsize=(8, 6))
sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
plt.xlabel('Sales Category')
plt.ylabel('Price')
plt.title('เปรียบเทียบราคา: สินค้าขายดี vs. สินค้าอื่นๆ')
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of Box Plot Comparing Prices: Best Sellers vs Others]
# Out:
# <ipython-input-58-e6608277c31b>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
# <ipython-input-58-e6608277c31b>:8: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
# <ipython-input-58-e6608277c31b>:12: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-58-e6608277c31b>:12: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# สร้าง Column 'Sales Category' แบ่งเป็น 'Best Seller' และ 'Others' โดยใช้ Top 10 ประเภทสินค้าขายดีจากข้อ 4.1
best_seller_types_list = best_selling_types_qty.index.tolist() # List ของประเภทสินค้าขายดี Top 10
df_all['Sales_Category'] = df_all['Type'].apply(lambda type: 'Best Seller' if type in best_seller_types_list else 'Others')

plt.figure(figsize=(8, 6))
sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
plt.xlabel('Sales Category')
plt.ylabel('Price')
plt.title('เปรียบเทียบราคา: สินค้าขายดี vs. สินค้าอื่นๆ')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-59-6c0b7ffe98ea>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
# <ipython-input-59-6c0b7ffe98ea>:6: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   sns.boxplot(x='Sales_Category', y='Price', data=df_all, palette=['#4c72b0', '#dd8452']) # ใช้ palette สี contrasting
# <ipython-input-59-6c0b7ffe98ea>:10: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-59-6c0b7ffe98ea>:10: UserWarning: Glyph 3611 (\N{THAI CHARACTER PO PLA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
# 5.2 ลูกค้าในแต่ละพื้นที่นิยมสินค้าประเภทไหน (Bar Chart - Top Types per Province)
top_types_per_province = df_all.groupby(['Address', 'Type_Eng'])['Quantity'].sum().groupby(level=0).nlargest(5).reset_index(level=0, drop=True).reset_index()
# หา Top 5 ประเภทสินค้าที่ขายดีที่สุดในแต่ละจังหวัด

# สร้าง FacetGrid เพื่อแสดง Bar Chart แยกตามจังหวัด
g = sns.FacetGrid(top_types_per_province, col='Province', col_wrap=4, height=4, aspect=1.2) # แบ่งกราฟตามจังหวัด, 4 คอลัมน์ต่อแถว
g.map(sns.barplot, 'Quantity', 'Type_Eng', palette='viridis') # สร้าง Bar Chart ในแต่ละ Facet (จังหวัด)

# ปรับแต่ง FacetGrid
g.set_titles(col_template="{col_name}") # ใช้ชื่อจังหวัดเป็น Title ของแต่ละ Facet
g.set_axis_labels('Total Quantity Sold', 'Product Type') # Label แกนรวม
for ax in g.axes.flat: # ปรับแต่งแต่ละ Axes (กราฟย่อย)
    ax.set_xlabel('Total Quantity Sold') # Label แกน X ของแต่ละกราฟย่อย
    ax.set_ylabel('Product Type') # Label แกน Y ของแต่ละกราฟย่อย
    ax.invert_yaxis() # เรียง Bar Chart จากมากไปน้อย

g.fig.suptitle('ประเภทสินค้าขายดีที่สุดในแต่ละจังหวัด (Top 5)', y=1.05) # Title ใหญ่ของ FacetGrid
plt.tight_layout()
plt.show()
# แสดงผลเป็น [Image of FacetGrid of Top 5 Product Types per Province]
